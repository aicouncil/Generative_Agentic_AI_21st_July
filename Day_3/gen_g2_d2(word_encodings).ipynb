# %%
doc = [
    "Rajiv is a good cricket player",
    "Sanjay is bad chess player"
    ]

print(doc)
# Out:
# ['Rajiv is a good cricket player', 'Sanjay is bad chess player']

# %% [markdown]
# **BOW Representation**

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(binary=True)
vectorizer.fit(doc)

bag_matrix = vectorizer.transform(doc)

# %%
print(vectorizer.get_feature_names_out())
# Out:
# ['bad' 'chess' 'cricket' 'good' 'is' 'player' 'rajiv' 'sanjay']

# %%
import pandas as pd
pd.DataFrame(bag_matrix.toarray(), columns = vectorizer.get_feature_names_out())
# Out:
#    bad  chess  cricket  good  is  player  rajiv  sanjay
# 0    0      0        1     1   1       1      1       0
# 1    1      1        0     0   1       1      0       1

# %% [markdown]
# **Limitations**
#   * No semantic understanding
#   * Ignores word orders and gramers
#   * Out of vocabulary words are simply ignored when we use a trained model

# %% [markdown]
# **TF-IDF encoding using python**

# %%
docs = [
    "AI is the future",
    "AI and ML are the future",
    "Physics is an intresting subject",
    "I am intrested in the cocepts of physics"
]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

vectorizer.fit(docs)

vectorizer.get_feature_names_out()
# Out:
# array(['ai', 'am', 'an', 'and', 'are', 'cocepts', 'future', 'in',
#        'intrested', 'intresting', 'is', 'ml', 'of', 'physics', 'subject',
#        'the'], dtype=object)

# %%
tf_idf_matrix = vectorizer.transform(docs)

# %%
pd.DataFrame(tf_idf_matrix.toarray(), columns = vectorizer.get_feature_names_out())
# Out:
#          ai        am        an  ...   physics   subject       the
# 0  0.523035  0.000000  0.000000  ...  0.000000  0.000000  0.423442
# 1  0.365594  0.000000  0.000000  ...  0.000000  0.000000  0.295980
# 2  0.000000  0.000000  0.485461  ...  0.382743  0.485461  0.000000
# 3  0.000000  0.407265  0.000000  ...  0.321093  0.000000  0.259952
#
# [4 rows x 16 columns]

# %% [markdown]
# * No semantic understanding
# * Ignores word orders and gramers
